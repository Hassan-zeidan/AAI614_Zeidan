# %% [markdown]
# <a href="https://colab.research.google.com/github/Hassan-zeidan/AAI614_Zeidan/blob/main/week%203/assignment%201/Notebook3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 3.1: Practice with Data Collections*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI614/blob/main/Week%203/Notebook3.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Source: Scraping with Python http://shop.oreilly.com/product/0636920034391.do

# %%
from urllib.request import urlopen , Request
from bs4 import BeautifulSoup
import ssl

req = Request(
    'https://en.wikipedia.org/wiki/Kevin_Bacon',
    headers={'User-Agent': 'Mozilla/5.0'}
)
with urlopen(req, timeout=15) as resp:
    html = resp.read()
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:SpecialPages
# /wiki/Main_Page
# /wiki/Special:Search
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Other_ventures
# #Six_Degrees_of_Kevin_Bacon
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://be.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%B0%D0%BD
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://uz.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# //en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard
# /w/index.php?title=Kevin_Bacon&oldid=1307865395
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1307865395&wpFormIdentifier=titleform
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_The_Best_You_Can-55_(cropped).jpg
# /wiki/Tribeca_Festival
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# http://baconbros.com
# #cite_note-1
# #cite_note-actor-2
# /wiki/Leading_man
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/Balto_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/X-Men:_First_Class
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# #cite_note-3
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-4
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# #cite_note-5
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# #cite_note-actor-2
# /wiki/Birth_name#Maiden_and_married_names
# #cite_note-actor-2
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# #cite_note-bacon-6
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# #cite_note-7
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# #cite_note-8
# /wiki/Glory_Van_Scott
# #cite_note-walk-9
# #cite_note-bacon-6
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-10
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-6
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-11
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-12
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-13
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-14
# /wiki/Footloose_(1984_film)
# #cite_note-bio-12
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-15
# #cite_note-bacon-6
# #cite_note-16
# #cite_note-17
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# #cite_note-18
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-12
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-19
# /wiki/Tremors_(1990_film)
# #cite_note-20
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-12
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-12
# /wiki/The_New_York_Times
# #cite_note-nyt94-21
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-22
# /wiki/A_Few_Good_Men_(film)
# #cite_note-23
# /wiki/Michael_Greif
# #cite_note-bio-12
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-12
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-12
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-24
# /wiki/Sleepers_(film)
# #cite_note-25
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-12
# /wiki/Losing_Chase
# #cite_note-austin-26
# /wiki/Digging_to_China
# #cite_note-bio-12
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-12
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-27
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-28
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-29
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-30
# /wiki/My_Dog_Skip_(film)
# #cite_note-31
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-32
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-33
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_05_(21267276740).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-34
# #cite_note-35
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-36
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-37
# #cite_note-38
# /wiki/The_Following
# #cite_note-39
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-40
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-41
# /wiki/Tremors_5:_Bloodline
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-42
# /wiki/Instagram
# #cite_note-43
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# #cite_note-44
# /wiki/EE_(telecommunications)
# #cite_note-45
# #cite_note-46
# #cite_note-47
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/File:Kevin_Bacon_2_SDCC_2014.jpg
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-48
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-49
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-50
# /wiki/File:Kyra_Sedgwick_and_Kevin_Bacon_The_Best_You_Can-28_(cropped).jpg
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-10
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-51
# /wiki/Tracy_Pollan
# #cite_note-52
# /wiki/Separation_of_church_and_state_in_the_United_States
# #cite_note-53
# #cite_note-54
# /wiki/The_Times
# /wiki/Atheism
# #cite_note-55
# /wiki/Antireligion
# #cite_note-56
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Wikipedia:Citation_needed
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-57
# #cite_note-58
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-59
# #cite_note-60
# #cite_note-61
# #cite_note-62
# /wiki/Apollo_13_(film)
# #cite_note-63
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-64
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-65
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-66
# /wiki/Denver_Film_Festival
# #cite_note-67
# /wiki/Phoenix_Film_Festival
# #cite_note-68
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-69
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-70
# /wiki/Seattle_International_Film_Festival
# #cite_note-71
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_2-0
# #cite_ref-actor_2-1
# #cite_ref-actor_2-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-3
# https://www.hollywoodreporter.com/tv/tv-news/showtime-cancels-city-on-a-hill-3-seasons-1235250089/
# /wiki/The_Hollywood_Reporter
# #cite_ref-4
# http://www.walkoffame.com/kevin-bacon
# /wiki/Hollywood_Walk_of_Fame
# #cite_ref-5
# https://www.marketingweek.com/ee-unveils-six-degrees-of-bacon-launch-ads/
# /wiki/Marketing_Week
# #cite_ref-bacon_6-0
# #cite_ref-bacon_6-1
# #cite_ref-bacon_6-2
# #cite_ref-bacon_6-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-7
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-8
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-walk_9-0
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-cosmo91_10-0
# #cite_ref-cosmo91_10-1
# #cite_ref-11
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_12-0
# #cite_ref-bio_12-1
# #cite_ref-bio_12-2
# #cite_ref-bio_12-3
# #cite_ref-bio_12-4
# #cite_ref-bio_12-5
# #cite_ref-bio_12-6
# #cite_ref-bio_12-7
# #cite_ref-bio_12-8
# #cite_ref-bio_12-9
# #cite_ref-bio_12-10
# https://web.archive.org/web/20160530033240/http://www.pbs.org/weta/finding-your-roots/profiles/kevin-bacon%c2%a0/
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_13-0
# https://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-14
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_15-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-16
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-17
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-18
# https://www.mentalfloss.com/article/71594/14-moving-facts-about-planes-trains-and-automobiles
# #cite_ref-19
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-20
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_21-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-22
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-23
# https://www.tcm.com/this-month/article/143158
# #cite_ref-24
# https://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-25
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_26-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-27
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-28
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-29
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-30
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-31
# https://archive.nytimes.com/www.nytimes.com/library/film/011200skip-film-review.html
# #cite_ref-32
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-33
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-34
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-35
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_36-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_37-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-38
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-39
# http://www.fox.com/the-following/
# #cite_ref-40
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-41
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-42
# http://baconbros.com/
# #cite_ref-43
# https://www.instagram.com/p/ClUvj92p4Qn/?hl=en
# #cite_ref-44
# https://www.marvel.com/articles/tv-shows/guardians-of-the-galaxy-holiday-special-soundtrack
# #cite_ref-45
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-46
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-47
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# /wiki/CNN
# #cite_ref-48
# http://www.sixdegrees.org/
# #cite_ref-49
# https://web.archive.org/web/20160414012427/http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-50
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-51
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-52
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-53
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-54
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-55
# #cite_ref-56
# https://www.foxnews.com/story/the-bacon-brothers-go-on-the-record
# #cite_ref-financialpost_57-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-58
# #cite_ref-59
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-60
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-61
# http://www.drawtheline.org/sign-now/
# #cite_ref-62
# https://web.archive.org/web/20190214002809/http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-63
# https://web.archive.org/web/20190520150327/http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-64
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-65
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-66
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-67
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-68
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-69
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-70
# https://archive.today/20180123031007/http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-71
# https://www.imdb.com/event/ev0000600/2015/1/
# /wiki/File:Commons-logo.svg
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb_(identifier)
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# https://web.archive.org/web/http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# /wiki/Special:EditPage/Template:Kevin_Bacon
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(composer)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:American_Riviera_Award
# /wiki/Template_talk:American_Riviera_Award
# /wiki/Special:EditPage/Template:American_Riviera_Award
# /wiki/Santa_Barbara_International_Film_Festival#American_Riviera_Award
# /wiki/Diane_Lane
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Tommy_Lee_Jones
# /wiki/Mickey_Rourke
# /wiki/Sandra_Bullock
# /wiki/Annette_Bening
# /wiki/Martin_Scorsese
# /wiki/Quentin_Tarantino
# /wiki/Robert_Redford
# /wiki/Patricia_Arquette
# /wiki/Ethan_Hawke
# /wiki/Michael_Keaton
# /wiki/Rachel_McAdams
# /wiki/Mark_Ruffalo
# /wiki/Jeff_Bridges
# /wiki/Sam_Rockwell
# /wiki/Viggo_Mortensen
# /wiki/Ren%C3%A9e_Zellweger
# /wiki/Delroy_Lindo
# /wiki/Kristen_Stewart
# /wiki/Brendan_Fraser
# /wiki/Mark_Ruffalo
# /wiki/Zoe_Salda%C3%B1a
# /wiki/39th_Santa_Barbara_International_Film_Festival
# /wiki/40th_Santa_Barbara_International_Film_Festival
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Special:EditPage/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Adrien_Brody
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Special:EditPage/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Special:EditPage/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Colin_Farrell
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Special:EditPage/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# https://isni.org/isni/0000000121291300
# https://viaf.org/viaf/39570812
# https://id.worldcat.org/fast/242183
# https://id.oclc.org/worldcat/entity/E39PBJyWTmRrCjK87VWCKb9v73
# https://d-nb.info/gnd/124109659
# https://id.loc.gov/authorities/n88034930
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://nla.gov.au/anbd.aut-an36021861
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# https://datos.bne.es/resource/XX1298810
# http://data.bibliotheken.nl/id/thes/p147880998
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://lod.nl.go.kr/resource/KAC2020K8226
# https://dbn.bn.org.pl/descriptor-details/9810630778405606
# https://www.nli.org.il/en/authorities/987007454685905171
# https://cantic.bnc.cat/registre/981061093903206706
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# https://trove.nla.gov.au/people/1189569
# https://www.idref.fr/067287832
# https://snaccooperative.org/ark:/99166/w6w67gw2
# https://lux.collections.yale.edu/view/person/9de11169-94a4-48f0-aadd-2efa69eb1552
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1307865395
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:Male_actors_from_Manhattan
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:Bacon_family_(United_States)
# /wiki/Category:CS1:_unfit_URL
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_American_English_from_April_2023
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Use_mdy_dates_from_April_2023
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_June_2025
# /wiki/Category:All_Wikipedia_articles_in_need_of_updating
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_June_2025
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# https://wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://www.wikimedia.org/
# https://www.mediawiki.org/
# #
# #
# #
# #
# #
# #
# #
# #
# #

# %% [markdown]
# ## Retrieving Articles Only

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import re

req= Request('https://en.wikipedia.org/wiki/Kevin_Bacon',headers={'User-Agent': 'Mozilla/5.0'})
with urlopen(req, timeout=15) as resp:
    html = resp.read()

bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Tribeca_Festival
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/Balto_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Birth_name#Maiden_and_married_names
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Marketing_Week
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(composer)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Santa_Barbara_International_Film_Festival#American_Riviera_Award
# /wiki/Diane_Lane
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Tommy_Lee_Jones
# /wiki/Mickey_Rourke
# /wiki/Sandra_Bullock
# /wiki/Annette_Bening
# /wiki/Martin_Scorsese
# /wiki/Quentin_Tarantino
# /wiki/Robert_Redford
# /wiki/Patricia_Arquette
# /wiki/Ethan_Hawke
# /wiki/Michael_Keaton
# /wiki/Rachel_McAdams
# /wiki/Mark_Ruffalo
# /wiki/Jeff_Bridges
# /wiki/Sam_Rockwell
# /wiki/Viggo_Mortensen
# /wiki/Ren%C3%A9e_Zellweger
# /wiki/Delroy_Lindo
# /wiki/Kristen_Stewart
# /wiki/Brendan_Fraser
# /wiki/Mark_Ruffalo
# /wiki/Zoe_Salda%C3%B1a
# /wiki/39th_Santa_Barbara_International_Film_Festival
# /wiki/40th_Santa_Barbara_International_Film_Festival
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Adrien_Brody
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Colin_Farrell
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import re

req = Request('http://en.wikipedia.org/wiki/Kevin_Bacon',headers={'User-Agent': 'Mozilla/5.0'})
with urlopen(req, timeout=15) as resp:
    html = resp.read()
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Tribeca_Festival
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/Balto_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Birth_name#Maiden_and_married_names
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Marketing_Week
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(composer)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Santa_Barbara_International_Film_Festival#American_Riviera_Award
# /wiki/Diane_Lane
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Tommy_Lee_Jones
# /wiki/Mickey_Rourke
# /wiki/Sandra_Bullock
# /wiki/Annette_Bening
# /wiki/Martin_Scorsese
# /wiki/Quentin_Tarantino
# /wiki/Robert_Redford
# /wiki/Patricia_Arquette
# /wiki/Ethan_Hawke
# /wiki/Michael_Keaton
# /wiki/Rachel_McAdams
# /wiki/Mark_Ruffalo
# /wiki/Jeff_Bridges
# /wiki/Sam_Rockwell
# /wiki/Viggo_Mortensen
# /wiki/Ren%C3%A9e_Zellweger
# /wiki/Delroy_Lindo
# /wiki/Kristen_Stewart
# /wiki/Brendan_Fraser
# /wiki/Mark_Ruffalo
# /wiki/Zoe_Salda%C3%B1a
# /wiki/39th_Santa_Barbara_International_Film_Festival
# /wiki/40th_Santa_Barbara_International_Film_Festival
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Adrien_Brody
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Colin_Farrell
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell

# %% [markdown]
# ## Random Walk

# %%
from urllib.request import urlopen,Request
from bs4 import BeautifulSoup
import time
import random
import re


random.seed(time.time_ns())
def getLinks(articleUrl):
    req = Request(f'https://en.wikipedia.org{articleUrl}',
              headers={'User-Agent': 'Mozilla/5.0'})
    html = urlopen(req, timeout=15)

    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/James_Garner
# /wiki/Vera_Miles
# /wiki/Wichita_North_High_School
# /wiki/Wichita_State_University_Campus_of_Applied_Sciences_and_Technology
# /wiki/Cowley_College
# /wiki/Johnson_County_Cavaliers
# /wiki/College_soccer_in_the_United_States
# /wiki/NCAA_Division_II_women%27s_soccer_tournament
# /wiki/Mercy_Mavericks
# /wiki/Binghamton_University
# /wiki/The_Wall_Street_Journal
# /wiki/Doi_(identifier)
# /wiki/International_Standard_Recording_Code
# /wiki/Object_Constraint_Language
# /wiki/.QL
# /wiki/ISBL
# /wiki/Data_Analysis_Expressions
# /wiki/Query_plan
# /wiki/Comparison_of_multi-model_databases
# /wiki/Shard_(database_architecture)
# /wiki/Spanner_(database)
# /wiki/Relationship_between_Google_and_Wikipedia
# /wiki/United_States_v._Google_LLC_(2023)
# /wiki/Big_Tech
# /wiki/Comcast
# /wiki/Philadelphia_Flyers
# /wiki/2012_NHL_entry_draft
# /wiki/Baie-Comeau_Drakkar
# /wiki/Valentin_Zykov
# /wiki/2013_NHL_entry_draft
# /wiki/1991_NHL_entry_draft
# /wiki/Wayne_Gretzky
# /wiki/Jackie_Joyner-Kersee
# /wiki/Mary_Decker
# /wiki/Wang_Junxia
# /wiki/Athletics_at_the_2004_Summer_Olympics_%E2%80%93_Women%27s_5000_metres
# /wiki/Kirsi_Valasti
# /wiki/Long-distance_running
# /wiki/Fell_running
# /wiki/Geocaching
# /wiki/Eye_protection
# /wiki/International_Orienteering_Federation
# /wiki/World_Backgammon_Federation
# /wiki/United_States_Backgammon_Federation
# /wiki/United_States
# /wiki/ISBN_(identifier)
# /wiki/Outline_of_books
# /wiki/Scroll
# /wiki/Spain
# /wiki/Czechoslovakia
# /wiki/Carpathian_Ruthenia
# /wiki/ISBN_(identifier)
# /wiki/Prontor-Compur
# /wiki/ISO_10962
# /wiki/ISO_19092-2
# /wiki/SoftWare_Hash_IDentifier
# /wiki/ISO_6346
# /wiki/JPEG_XR
# /wiki/Pulse-code_modulation
# /wiki/Ferranti_Canada
# /wiki/Honeywell
# /wiki/Analog_Devices
# /wiki/Micron_Technology
# /wiki/Fidelity_Investments
# /wiki/Janus_Henderson
# /wiki/M%26G
# /wiki/NatWest_Group
# /wiki/Private_equity
# /wiki/Private_Equity_International
# /wiki/Private_equity
# /wiki/Den_of_Thieves_(Stewart_book)
# /wiki/Simon_%26_Schuster
# /wiki/Richard_E._Snyder
# /wiki/New_York_Times
# /wiki/List_of_awards_won_by_The_New_York_Times
# /wiki/Turner_Catledge
# /wiki/Washington,_D.C.
# /wiki/Interstate_95_in_the_District_of_Columbia
# /wiki/Interstate_395_(Virginia%E2%80%93District_of_Columbia)
# /wiki/WTOP-FM
# /wiki/W216CM
# /wiki/WHGT
# /wiki/WZXH
# /wiki/WSRN-FM
# /wiki/WKXW
# /wiki/WBMR
# /wiki/Radio_format
# /wiki/Ethnic
# /wiki/Urban_anthropology
# /wiki/Anthrozoology
# /wiki/Animal_welfare_and_rights_in_Canada
# /wiki/Animal_welfare_and_rights_in_South_Africa
# /wiki/South_Africa
# /wiki/Anguilla
# /wiki/Tokelau
# /wiki/Atafu
# /wiki/Brown_noddy
# /wiki/Species_description
# /wiki/Codes_of_nomenclature
# /wiki/Karl_Engelbrecht_Hirn
# /wiki/Finland
# /wiki/Wayback_Machine
# /wiki/Open_Archival_Information_System
# /wiki/British_Library
# /wiki/Booth_Papers
# /wiki/British_Museum_Reading_Room
# /wiki/Muhammad_Ali_Jinnah
# /wiki/Pakistan
# /wiki/Lists_of_Pakistani_films
# /wiki/Lollywood
# /wiki/Cinema_of_the_Soviet_Union
# /wiki/Lists_of_Soviet_films
# /wiki/List_of_Soviet_films_of_1980
# /wiki/List_of_Soviet_films_of_1935
# /wiki/List_of_Russian_films
# /wiki/List_of_Russian_films_of_1997
# /wiki/List_of_Russian_films_of_2024
# /wiki/Marat_Basharov
# /wiki/Pyotr_Bagration
# /wiki/Duchy_of_Brunswick
# /wiki/Evangelical_Lutheran_Church_in_Brunswick
# /wiki/Presbyterian_Church_in_Liberia
# /wiki/Reformed_church
# /wiki/Sunda_Wiwitan
# /wiki/Christianity_in_Indonesia
# /wiki/Indonesian_cuisine
# /wiki/List_of_Indonesian_drinks
# /wiki/Murtabak
# /wiki/Yusheng
# /wiki/Nasi_tumpang
# /wiki/X%C3%B4i
# /wiki/Khmer_Krom
# /wiki/Vietnamese_people
# /wiki/H%27tin_people
# /wiki/Indians_in_Thailand
# /wiki/Kra%E2%80%93Dai
# /wiki/Burushaski
# /wiki/Nadahup_languages
# /wiki/Taushiro_language
# /wiki/Rikbaktsa_language
# /wiki/Xokleng_language
# /wiki/Kr%E1%BA%BDje_language
# /wiki/Ingain_language
# /wiki/Masakar%C3%A1_language
# /wiki/Kayap%C3%B3_language
# /wiki/Baniwa_language_(disambiguation)
# /wiki/Banawa_language
# /wiki/Mamaind%C3%AA_language
# /wiki/Polysynthetic_language
# /wiki/Hokan_languages
# /wiki/Niger%E2%80%93Congo_languages
# /wiki/Akpes_language
# /wiki/Eruwa_language
# /wiki/Ukue_language
# /wiki/Voiced_labial%E2%80%93velar_approximant
# /wiki/Doi_(identifier)
# /wiki/ISO_10303-28
# /wiki/ISO_metric_screw_thread
# /wiki/ISO/IEC_27001
# /wiki/ISO/IEC_10967
# /wiki/IEC_60446
# /wiki/ISO/IEC_12207
# /wiki/Open_Document_Architecture
# /wiki/ISO/IEC_24744
# /wiki/IEC_61131-3
# /wiki/USB
# /wiki/Ethernet
# /wiki/Locally_administered_address
# /wiki/G.hn
# /wiki/Physical_layer
# /wiki/Media-independent_interface
# /wiki/Medium-dependent_interface
# /wiki/Ethernet_Alliance
# /wiki/Energy-Efficient_Ethernet
# /wiki/Carrier-sense_multiple_access_with_collision_detection
# /wiki/Collision_domain
# /wiki/Wi-Fi
# /wiki/Lee_de_Forest
# /wiki/Rashomon
# /wiki/Robert_F._Boyle
# /wiki/Terence_Marsh
# /wiki/Oliver!_(film)
# /wiki/Fagin
# /wiki/B%27nai_B%27rith
# /wiki/International_Council_of_Jewish_Women
# /wiki/United_Nations_Economic_and_Social_Council
# /wiki/Sweden
# /wiki/Belarus
# /wiki/Georgia_(country)
# /wiki/Olympic_weightlifting
# /wiki/Rhythmic_gymnastics
# /wiki/Tumbling_(sport)
# /wiki/Balance_beam
# /wiki/1954_World_Artistic_Gymnastics_Championships
# /wiki/2022_Trampoline_Gymnastics_World_Championships
# /wiki/Megu_Uyama
# /wiki/International_Olympic_Committee
# /wiki/International_Street_and_Ball_Hockey_Federation
# /wiki/P%C5%99erov
# /wiki/Karel_Nov%C3%A1%C4%8Dek
# /wiki/Stan_Wawrinka
# /wiki/Jo-Wilfried_Tsonga
# /wiki/Mark_Woodforde
# /wiki/Todd_Woodbridge
# /wiki/Robert_Kinsey
# /wiki/John_Bromwich
# /wiki/Eric_Sturgess
# /wiki/Jonas_Bj%C3%B6rkman
# /wiki/Mark_Woodforde
# /wiki/Anders_J%C3%A4rryd
# /wiki/1986_French_Open_%E2%80%93_Men%27s_doubles
# /wiki/Ryan_Harrison
# /wiki/Ion_%C8%9Airiac
# /wiki/Bill_Talbert
# /wiki/Storm_Hunter
# /wiki/WTA_Tour_Championships
# /wiki/1985_Virginia_Slims_Championships
# /wiki/1983_Virginia_Slims_World_Championship_Series
# /wiki/Wendy_White_(tennis)
# /wiki/Wimbledon_Championships
# /wiki/AELTC
# /wiki/List_of_Olympic_venues_in_discontinued_events
# /wiki/Tug_of_war_at_the_1912_Summer_Olympics
# /wiki/Sweden_at_the_1912_Summer_Olympics
# /wiki/Gunnar_Johnson
# /wiki/Swedish_Olympic_Committee
# /wiki/National_Olympic_Committee
# /wiki/Olympic_Committee_of_Bosnia_and_Herzegovina
# /wiki/Belarus_Olympic_Committee
# /wiki/Belarus_Athletic_Federation
# /wiki/Italian_Athletics_Federation
# /wiki/Romanian_Athletics_Federation
# /wiki/Salvadorian_Athletics_Federation
# /wiki/North_American,_Central_American_and_Caribbean_Athletic_Association
# /wiki/Nicaraguan_Athletics_Federation
# /wiki/Bolivian_Athletics_Federation
# /wiki/Panamanian_Athletics_Federation
# /wiki/Jamaica_Athletics_Administrative_Association
# /wiki/Gleaner_Company
# /wiki/The_Gleaner
# /wiki/ISBN_(identifier)
# /wiki/Codex
# /wiki/Ptolemaic_Kingdom
# /wiki/Diomedes_Soter
# /wiki/Maues
# /wiki/Spalirises
# /wiki/Indian_literature
# /wiki/Sangam_literature
# /wiki/Tamil_Heritage_Foundation
# /wiki/Mozhi_(transliteration)
# /wiki/A._C._Sreehari
# /wiki/Ulloor_S._Parameswara_Iyer
# /wiki/OCLC_(identifier)
# /wiki/Dublin,_Ohio
# /wiki/United_States_Census_Bureau
# /wiki/United_States_Electoral_College
# /wiki/Gouverneur_Morris
# /wiki/Philadelphia_Convention
# /wiki/Convention_to_propose_amendments_to_the_United_States_Constitution
# /wiki/List_of_amendments_to_the_Constitution_of_the_United_States
# /wiki/Federal_Marriage_Amendment
# /wiki/Executive_Order_13672
# /wiki/Barack_Obama
# /wiki/Harry_S._Truman
# /wiki/ISBN_(identifier)
# /wiki/Paperback
# /wiki/Miniature_book
# /wiki/Tsundoku
# /wiki/Outline_of_books
# /wiki/Book_publishers_in_Upper_Canada
# /wiki/List_of_Canadian_short_story_writers
# /wiki/Alistair_MacLeod
# /wiki/Port_Hood_Island,_Nova_Scotia
# /wiki/Mabou,_Nova_Scotia
# /wiki/Cape_Breton_University
# /wiki/Bras_d%27Or,_Nova_Scotia
# /wiki/Leitches_Creek
# /wiki/Cape_Breton_Regional_Hospital
# /wiki/Shunacadie
# /wiki/Mi%27kmaq_language
# /wiki/Listuguj_Mi%27gmaq_First_Nation
# /wiki/Battle_of_Restigouche
# /wiki/Lunenburg_campaign_(1758)
# /wiki/Northeast_Coast_Campaign_(1746)
# /wiki/North_Yarmouth,_Maine
# /wiki/New_England_town
# /wiki/Bradford,_Massachusetts
# /wiki/Geographic_coordinate_system
# /wiki/International_Terrestrial_Reference_System
# /wiki/NAD_83
# /wiki/Chicago
# /wiki/Bosnian_Americans
# /wiki/Turkish_Americans
# /wiki/Burhan_Do%C4%9Fan%C3%A7ay
# /wiki/The_National_Gallery_of_Art
# /wiki/George_Gordon_Meade_Memorial
# /wiki/List_of_public_art_in_Washington,_D.C.,_Ward_2
# /wiki/Cubi_XXVI
# /wiki/National_Gallery_of_Art_Sculpture_Garden
# /wiki/George_Rickey
# /wiki/Ball_bearing
# /wiki/Ball_screw
# /wiki/Jackscrew
# /wiki/Ball_screw
# /wiki/Boring_(manufacturing)
# /wiki/Gun_barrel
# /wiki/Elephant_gun
# /wiki/Field_strip
# /wiki/SKS
# /wiki/Russia
# /wiki/Social_entrepreneurship_in_Russia
# /wiki/Central_Russian_Upland
# /wiki/Outline_of_Russia
# /wiki/1739_in_Russia
# /wiki/1745_in_Russia
# /wiki/1753_in_Russia
# /wiki/Matvei_Platov
# /wiki/Crimean_Tatars
# /wiki/Annexation_of_Crimea_by_the_Russian_Federation
# /wiki/United_Nations_General_Assembly
# /wiki/Peter_Florin
# /wiki/UNESCO
# /wiki/Women_in_peacekeeping
# /wiki/Feminist_rhetoric
# /wiki/Reproductive_justice
# /wiki/S2CID_(identifier)
# /wiki/University_of_Chicago_Press
# /wiki/List_of_University_of_Chicago_Press_journals
# /wiki/Getty_Research_Institute
# /wiki/Alfredo_Boulton
# /wiki/Caracas
# /wiki/Baghdad
# /wiki/Al-Mansur
# /wiki/Dirhams
# /wiki/Oxford_English_Dictionary
# /wiki/Random_House_Webster%27s_Unabridged_Dictionary
# /wiki/Concise_Oxford_English_Dictionary
# /wiki/Oxford_English_Dictionary
# /wiki/Wayback_Machine
# /wiki/DMCA_request
# /wiki/WIPO_Lex
# /wiki/Utility_model
# /wiki/Pirate_Party
# /wiki/Hacker_culture
# /wiki/Late_Middle_English
# /wiki/Yogh
# /wiki/Latin_alpha
# /wiki/Esh_(letter)
# /wiki/Logogram
# /wiki/Sitelen_Pona
# /wiki/Isotype_(picture_language)
# /wiki/Gerd_Arntz
# /wiki/Modernist
# /wiki/Tom_Otterness
# /wiki/National_Academy_Museum
# /wiki/Bemelmans_Bar
# /wiki/Daniel_(restaurant)
# /wiki/Bouley_at_Home
# /wiki/Second_Avenue_Deli
# /wiki/Odo_(restaurant)
# /wiki/Penny_Cafeteria
# /wiki/List_of_vegetarian_restaurants
# /wiki/List_of_Michelin-starred_restaurants_in_Malta
# /wiki/List_of_Turkish_restaurants
# /wiki/List_of_sushi_restaurants
# /wiki/Sukiyabashi_Jiro
# /wiki/Jiro_Dreams_of_Sushi
# /wiki/The_Guardian
# /wiki/The_100_Best_Female_Footballers_in_the_World
# /wiki/Olympique_Lyonnais_(Women)
# /wiki/%C3%89lodie_Thomis
# /wiki/Jessica_Houara
# /wiki/Marie-Laure_Delie
# /wiki/Sinsheim
# /wiki/Heddesbach
# /wiki/Geographic_coordinate_system
# /wiki/Linux
# /wiki/Mark_Galassi
# /wiki/Cygnus_Solutions
# /wiki/FreeOTP
# /wiki/Red_Hat_Enterprise_Linux_derivatives
# /wiki/CentOS
# /wiki/Arch_Linux
# /wiki/BlackArch
# /wiki/Remix_OS
# /wiki/Pop!_OS
# /wiki/BlackArch
# /wiki/4MLinux
# /wiki/TopologiLinux
# /wiki/Linux_from_Scratch
# /wiki/Pinguy_OS
# /wiki/Uruk_GNU/Linux
# /wiki/Android-x86#Project_Celadon
# /wiki/Calculate_Linux
# /wiki/TopologiLinux
# /wiki/Think_Blue_Linux
# /wiki/XB_Machine
# /wiki/Patrick_K._Kroupa
# /wiki/Software_cracking
# /wiki/SoftICE
# /wiki/Source_code
# /wiki/Execution_(computing)
# /wiki/Vector_processor
# /wiki/Gather-scatter
# /wiki/Single_Instruction_Multiple_Data
# /wiki/Clock_rate
# /wiki/Static_core
# /wiki/65C816
# /wiki/Super_Nintendo_Entertainment_System
# /wiki/RCA
# /wiki/Sky_M%C3%A9xico
# /wiki/UA-Columbia_Cablevision
# /wiki/Insight_Communications
# /wiki/HSN
# /wiki/3ABN_Latino
# /wiki/TVNZ%2B
# /wiki/Telasa
# /wiki/WWE_Network
# /wiki/2007_WWE_Draft
# /wiki/List_of_WWE_personnel
# /wiki/Seth_Rollins
# /wiki/Curb_stomp
# /wiki/YouTube
# /wiki/Boing_Boing
# /wiki/Unicorn
# /wiki/Hinckaert_knot
# /wiki/Carnation_(heraldry)
# /wiki/Abatement_(heraldry)
# /wiki/Boars_in_heraldry
# /wiki/Mantle_and_pavilion_(heraldry)
# /wiki/Equestrian_seal
# /wiki/Oak#Regional_and_state
# /wiki/Bilinga_(wood)
# /wiki/Nauclea_diderrichii
# /wiki/Chamfer
# /wiki/Razee_plane
# /wiki/Shoulder_plane
# /wiki/Japanese_plane
# /wiki/Plane_(tool)
# /wiki/Rubberwood
# /wiki/Paint
# /wiki/Visual_pollution
# /wiki/Marine_debris
# /wiki/S2CID_(identifier)
# /wiki/Imprint_(trade_name)
# /wiki/Review_article
# /wiki/AMiner_(database)
# /wiki/Data_mining
# /wiki/Policy_gradient_method
# /wiki/Huawei_PanGu
# /wiki/Huawei_U1250
# /wiki/Smart_device
# /wiki/Telephone_tapping
# /wiki/ISBN_(identifier)
# /wiki/International_Standard_Text_Code
# /wiki/ISO_13490
# /wiki/ISO_15022
# /wiki/ECMAScript_for_XML
# /wiki/MaxiCode
# /wiki/ISO_25964
# /wiki/ISO_15924
# /wiki/ISO_3166
# /wiki/International_Civil_Aviation_Organization
# /wiki/Comprehensive_Nuclear-Test-Ban_Treaty
# /wiki/List_of_members_of_the_United_Nations_Security_Council
# /wiki/Somali_Democratic_Republic
# /wiki/Cold_War
# /wiki/Drug_policy_of_the_Soviet_Union
# /wiki/Propaganda_in_the_Soviet_Union
# /wiki/COMECON
# /wiki/Treaty_of_Campo_Formio
# /wiki/Jean-Baptiste_Robert_Lindet
# /wiki/Pierre_Pflimlin
# /wiki/Charles_Dupuy
# /wiki/Gabriel_Hanotaux
# /wiki/Th%C3%A9ophile_Delcass%C3%A9
# /wiki/Louis_Pierre_%C3%89douard,_Baron_Bignon
# /wiki/Th%C3%A9ophile_Delcass%C3%A9
# /wiki/Diphenylamine
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_8652
# /wiki/ISO_639-2
# /wiki/SQL
# /wiki/Motion_JPEG_2000
# /wiki/International_Standard_Identifier_for_Libraries_and_Related_Organizations
# /wiki/IEC_62682
# /wiki/IEC_62351
# /wiki/Industrial_control_system
# /wiki/Distributed_control_system
# /wiki/FPSO
# /wiki/Atlantic_Ocean
# /wiki/Mediterranean_Rim
# /wiki/Mediterranean_Basin
# /wiki/Asia
# /wiki/Arctic
# /wiki/SS_Roosevelt_(1905)
# /wiki/Miguel_Corte-Real
# /wiki/Willem_Barentsz
# /wiki/Surname
# /wiki/Finnish_name
# /wiki/List_of_one-word_stage_names
# /wiki/Abradab
# /wiki/London
# /wiki/Prime_meridian_(Greenwich)
# /wiki/Exclusive_economic_zone
# /wiki/Jersey
# /wiki/Azerbaijan
# /wiki/Pakistan
# /wiki/Raza_Rumi
# /wiki/ISBN_(identifier)
# /wiki/History_of_books
# /wiki/Book_swapping
# /wiki/Edition_(book)
# /wiki/Charles_Scribner%27s_Sons
# /wiki/Kohlberg_Kravis_Roberts
# /wiki/Library_Journal
# /wiki/Volusia_County
# /wiki/Per_capita_income
# /wiki/List_of_Guam_locations_by_per_capita_income
# /wiki/List_of_Nevada_locations_by_per_capita_income
# /wiki/Rachel,_Nevada
# /wiki/Alamo,_Nevada
# /wiki/Fay,_Nevada
# /wiki/Time_zone
# /wiki/Time_in_the_Falkland_Islands
# /wiki/Time_in_Trinidad_and_Tobago
# /wiki/Time_in_Panama
# /wiki/Time_in_the_Dominican_Republic
# /wiki/America/Santo_Domingo
# /wiki/America/Santo_Domingo
# /wiki/Time_in_Grenada
# /wiki/Time_zone
# /wiki/North_Carolina
# /wiki/Major_League_Soccer
# /wiki/Apple_TV_app
# /wiki/MacOS_Server
# /wiki/Apple_Lisa
# /wiki/PowerBook_Duo_230
# /wiki/Macintosh_IIvi
# /wiki/Apple_IIGS
# /wiki/Interrupt
# /wiki/Object-oriented_operating_system
# /wiki/Unix
# /wiki/Plan_9_from_Bell_Labs
# /wiki/Unix
# /wiki/Oracle_Solaris
# /wiki/Service_Management_Facility
# /wiki/Init
# /wiki/Man_page
# /wiki/Nginx
# /wiki/Traefik_Proxy
# /wiki/Monkey_HTTP_Server
# /wiki/Xitami
# /wiki/Zeus_Web_Server
# /wiki/Riverbed_Technology
# /wiki/Wayback_Machine
# /wiki/Internet_Archive_Scholar
# /wiki/American_Libraries_(collection)
# /wiki/University_of_Massachusetts_Lowell
# /wiki/Northern_Essex_Community_College
# /wiki/Merrimack_Valley
# /wiki/Northern_Essex_Community_College
# /wiki/Hyannis_State_Teachers_College
# /wiki/Roxbury_Community_College
# /wiki/Boston_Architectural_College
# /wiki/New_England_Conservatory_of_Music
# /wiki/Ella_Jenkins
# /wiki/Wayback_Machine
# /wiki/Linux
# /wiki/PHP
# /wiki/Destructor_(computer_science)
# /wiki/Addison-Wesley
# /wiki/TCP/IP_Illustrated
# /wiki/4.4BSD-Lite
# /wiki/DARPA
# /wiki/Remote-controlled_insect
# /wiki/Wildlife_farming
# /wiki/Victoria_Braithwaite
# /wiki/Sharon_Pincott
# /wiki/OneKind
# /wiki/Shirley_McGreal
# /wiki/Mobberley,_Cheshire
# /wiki/Siddington,_Cheshire
# /wiki/Peover_Inferior
# /wiki/Higher_Hurdsfield
# /wiki/Snelson,_Cheshire
# /wiki/Middlewich
# /wiki/Nantwich
# /wiki/Encyclop%C3%A6dia_Britannica_Eleventh_Edition
# /wiki/ISBN_(identifier)
# /wiki/Novel
# /wiki/The_Sorrows_of_Young_Werther
# /wiki/ISSN_(identifier)
# /wiki/ISO/IEC_12207
# /wiki/ISO_13490
# /wiki/ISO_2014
# /wiki/MathML
# /wiki/CSS_animations
# /wiki/Inbetweening
# /wiki/History_of_animation_in_India
# /wiki/Model_sheet
# /wiki/List_of_animation_studios
# /wiki/Puppet
# /wiki/Morph_target_animation
# /wiki/Walk_cycle
# /wiki/Filipino_animation
# /wiki/Manila_Standard
# /wiki/Rodrigo_Duterte
# /wiki/Vice_President_of_the_Philippines
# /wiki/Government_of_the_Philippines
# /wiki/Executive_departments_of_the_Philippines
# /wiki/Names_of_the_Philippines
# /wiki/Sex_trafficking_in_the_Philippines
# /wiki/Sex_trafficking_in_Indonesia
# /wiki/Blue_Dragon_Children%27s_Foundation
# /wiki/Australia
# /wiki/Heard_Island_and_McDonald_Islands
# /wiki/Mollusk
# /wiki/Animal
# /wiki/Orthonectida
# /wiki/Colponemid
# /wiki/Candidatus_Aenigmatarchaeum
# /wiki/Thermodesulfobacteriota
# /wiki/PMID_(identifier)
# /wiki/PMID_(identifier)
# /wiki/CORE_(research_service)
# /wiki/Petr_Knoth
# /wiki/2005_World_Junior_Figure_Skating_Championships
# /wiki/Spain
# /wiki/Moorish_architecture
# /wiki/Court_of_the_Lions
# /wiki/Palacio_de_los_Olvidados
# /wiki/Gallows
# /wiki/Rope
# /wiki/Life-critical
# /wiki/Underwater_exploration
# /wiki/Aerosinusitis
# /wiki/Water_safety
# /wiki/Tham_Luang_cave_rescue
# /wiki/Josef_Schmid_(flight_surgeon)
# /wiki/Fitness_to_dive
# /wiki/Diver_training_standard
# /wiki/National_Association_of_Underwater_Instructors
# /wiki/Middle_ear_barotrauma
# /wiki/Timeline_of_atmospheric_diving_suits
# /wiki/American_Canadian_Underwater_Certifications
# /wiki/Offshore_construction
# /wiki/National_Association_of_Underwater_Instructors
# /wiki/Diving_Medical_Practitioner
# /wiki/Recreational_diving
# /wiki/Conf%C3%A9d%C3%A9ration_Mondiale_des_Activit%C3%A9s_Subaquatiques
# /wiki/Diving_disorders
# /wiki/Steve_Parish
# /wiki/Aluminaut
# /wiki/Shadow_Divers
# /wiki/Dive_planning
# /wiki/Nautical_Archaeology_Program
# /wiki/Natalia_Molchanova
# /wiki/Mechanism_of_diving_regulators
# /wiki/General_gas_equation
# /wiki/Vis_viva
# /wiki/Monadology
# /wiki/Calculus_ratiocinator
# /wiki/Theodicy
# /wiki/N._T._Wright
# /wiki/Jonathan_Kimberley
# /wiki/Lancelot_Addison
# /wiki/Joseph_Hunkin_(bishop)
# /wiki/George_Arbuthnot_(priest)
# /wiki/Claude_Blagden
# /wiki/Theodore_Woods
# /wiki/Diocese_of_Winchester
# /wiki/William_of_Wykeham
# /wiki/Herefrith
# /wiki/Frithestan
# /wiki/%C3%86lfwine_of_Winchester
# /wiki/Christianity
# /wiki/Thirty_Years%27_War
# /wiki/JSTOR_(identifier)
# /wiki/PMC_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISO_1000
# /wiki/ISO/IEEE_11073
# /wiki/ISO_8178
# /wiki/Torx
# /wiki/Slot_head
# /wiki/Lockheed_SR-71_Blackbird
# /wiki/Lockheed_XB-30
# /wiki/Lockheed_P-2_Neptune
# /wiki/Lockheed_C-141_Starlifter
# /wiki/Hurlburt_Field
# /wiki/Umatilla_Municipal_Airport
# /wiki/Naval_Air_Station_Cecil_Field
# /wiki/C-12_Huron
# /wiki/Boeing_C-32
# /wiki/Boeing_314_Clipper
# /wiki/Boeing_XB-15
# /wiki/Bombardier_Challenger_600_series
# /wiki/Lockheed_Model_9_Orion
# /wiki/Fokker_F-10
# /wiki/Dornier_328
# /wiki/Malta
# /wiki/ISSN_(identifier)
# /wiki/ISO_8000
# /wiki/ISO_15926
# /wiki/Valhall_oil_field
# /wiki/Tor_Formation
# /wiki/Carboniferous
# /wiki/Tian_Shan
# /wiki/Yunling_Mountains
# /wiki/Wuding_County
# /wiki/Changning_County,_Yunnan
# /wiki/Lianghe_County
# /wiki/D%C3%AAq%C3%AAn_Tibetan_Autonomous_Prefecture
# /wiki/New_Taipei
# /wiki/Beimen_District
# /wiki/Cijin_District
# /wiki/Orchid_Island
# /wiki/Fenyuan
# /wiki/Shengang,_Changhua
# /wiki/Hsinchu_County
# /wiki/Hsinchu_County_Council
# /wiki/Keelung_City_Council
# /wiki/Keelung_City_Government
# /wiki/Taoyuan_City_Government
# /wiki/Hsinchu_City_Government
# /wiki/Republic_of_China_(1912%E2%80%931949)
# /wiki/Chinese_Civil_War
# /wiki/Revolutionary_Government_of_the_Armed_Forces_of_Peru
# /wiki/Cambodian_Civil_War
# /wiki/Australia_in_the_Vietnam_War
# /wiki/Arrest_and_assassination_of_Ng%C3%B4_%C4%90%C3%ACnh_Di%E1%BB%87m
# /wiki/B%E1%BB%ADu_H%E1%BB%99i
# /wiki/Hanoi
# /wiki/List_of_cities_in_Vietnam
# /wiki/Quy_Nhon
# /wiki/D%C4%A9_An
# /wiki/B%E1%BB%89m_S%C6%A1n
# /wiki/Nam_%C4%90%C3%A0n_district
# /wiki/Qu%E1%BA%A3ng_X%C6%B0%C6%A1ng_district
# /wiki/Th%E1%BB%8D_Xu%C3%A2n_district
# /wiki/Con_Cu%C3%B4ng_district
# /wiki/Laos
# /wiki/Lao_Issara
# /wiki/Elections_in_Laos
# /wiki/Dependent_territory
# /wiki/International_Court_of_Justice
# /wiki/Poland
# /wiki/Orders,_decorations,_and_medals_of_Poland
# /wiki/Military_decorations_of_Mexico
# /wiki/Orders,_decorations,_and_medals_of_Moldova
# /wiki/List_of_states_with_limited_recognition
# /wiki/Foreign_relations_of_Israel
# /wiki/1980_Liberian_coup_d%27%C3%A9tat
# /wiki/1983_Nigerian_coup_d%27%C3%A9tat
# /wiki/1977_Sudan_Juba_coup_attempt
# /wiki/2023_Burkina_Faso_coup_attempt
# /wiki/2021_Myanmar_coup_d%27%C3%A9tat
# /wiki/Philippines
# /wiki/Lumpia
# /wiki/Sapo_tahu
# /wiki/Sambal#Indonesia
# /wiki/Hainanese_chicken_rice
# /wiki/Sinampalukan
# /wiki/As%C3%ADn_tibuok
# /wiki/Pancit_buko
# /wiki/Bringhe
# /wiki/Pork
# /wiki/Red_meat
# /wiki/Intensive_animal_farming
# /wiki/Daniel_Mills_(biologist)
# /wiki/Pain_in_crustaceans
# /wiki/Declawing_of_crabs
# /wiki/Aquaculture_of_cobia
# /wiki/List_of_harvested_aquatic_animals_by_weight
# /wiki/Trout
# /wiki/Westslope_cutthroat_trout
# /wiki/ISBN_(identifier)
# /wiki/EAN-5
# /wiki/European_Article_Number
# /wiki/Universal_Product_Code
# /wiki/Data_Matrix
# /wiki/EDIFACT
# /wiki/Base32
# /wiki/Y2K_bug
# /wiki/Down_syndrome
# /wiki/Chromosome_14_(human)
# /wiki/Protein
# /wiki/Bibcode_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/PMID_(identifier)
# /wiki/PMC_(identifier)
# /wiki/Scientometrics
# /wiki/Horizon_scanning
# /wiki/Scientific_misconduct
# /wiki/Post-normal_science
# /wiki/Mapping_controversies
# /wiki/Academic_bias
# /wiki/Women%27s_rights
# /wiki/Portugal
# /wiki/Agriculture
# /wiki/Fossil_fuel
# /wiki/Feedstock
# /wiki/Kiln
# /wiki/Anagama_kiln
# /wiki/Pottery
# /wiki/Ali_Kosh
# /wiki/Neolithic
# /wiki/Debitage
# /wiki/Eden_point
# /wiki/Stallings_Island
# /wiki/Oneota
# /wiki/Ceremonial_pipe
# /wiki/Smoking_in_Macau
# /wiki/Smoking_in_New_Zealand
# /wiki/Tobacco
# /wiki/Recreational_use_of_nitrous_oxide
# /wiki/Emulsifier
# /wiki/Miniemulsion
# /wiki/Doi_(identifier)
# /wiki/ISO_639-1
# /wiki/Limburgish
# /wiki/ISBN_(identifier)
# /wiki/Simple_Features
# /wiki/SoftWare_Hash_IDentifier
# /wiki/Film_speed
# /wiki/JPEG
# /wiki/Hadamard_product_(matrices)
# /wiki/Identity_matrix
# /wiki/Unitary_matrix
# /wiki/State-transition_matrix
# /wiki/Pentadiagonal_matrix
# /wiki/Moore_matrix
# /wiki/List_of_matrices
# /wiki/Bioinformatics
# /wiki/NeXML_format
# /wiki/Australia_Bioinformatics_Resource
# /wiki/European_Molecular_Biology_Laboratory
# /wiki/Belgium
# /wiki/Functional_illiteracy
# /wiki/List_of_countries_by_literacy_rate
# /wiki/Education_in_Slovakia
# /wiki/Education_in_Liechtenstein
# /wiki/Education_in_Lithuania
# /wiki/Occupation_of_the_Baltic_states
# /wiki/Bialystok_District
# /wiki/Nazi_Germany
# /wiki/Feudal_fascism
# /wiki/Popular_front
# /wiki/Partisan_primary
# /wiki/Mixed-member_majoritarian_representation
# /wiki/Maximal_lottery
# /wiki/Semi-proportional_representation
# /wiki/Single_non-transferable_vote
# /wiki/Taiwan
# /wiki/Northern_Cyprus
# /wiki/Enosis
# /wiki/Maratha,_Santalaris_and_Aloda_massacre
# /wiki/1974_Cypriot_coup_d%27%C3%A9tat
# /wiki/Cyprus
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_7810
# /wiki/British_Standard_Pipe
# /wiki/ISO_1745
# /wiki/ISO_2145
# /wiki/Power_take-off
# /wiki/Clemson_University
# /wiki/Libertarian_Party_(United_States)
# /wiki/Virginia_Postrel
# /wiki/C-SPAN
# /wiki/CNN
# /wiki/Alhurra
# /wiki/Jerusalem
# /wiki/Mughrabi_Quarter
# /wiki/Rassco_(neighborhood)
# /wiki/Givat_Ram
# /wiki/David_Ben-Gurion
# /wiki/101_Squadron_(Israel)
# /wiki/135_Squadron_(Israel)
# /wiki/Operation_Mole_Cricket_19
# /wiki/SA-2
# /wiki/Command_guidance
# /wiki/S-25_Berkut
# /wiki/Nikita_Khrushchev
# /wiki/Winston_Churchill
# /wiki/Coningsby_(novel)
# /wiki/Right_Book_Club
# /wiki/Rab_Butler
# /wiki/Kenneth_Clarke
# /wiki/Stanley_Baldwin
# /wiki/Singapore_Naval_Base
# /wiki/HMS_Sultan_(shore_establishment)
# /wiki/Royal_Navy_other_rank_insignia
# /wiki/Warrant_officer_(United_Kingdom)#Royal_Navy
# /wiki/Twitter
# /wiki/Vero_(app)
# /wiki/Mobli
# /wiki/IOS
# /wiki/IOS_18
# /wiki/Clips_(software)
# /wiki/IPadOS_17
# /wiki/IPad_(3rd_generation)
# /wiki/Macintosh_Classic
# /wiki/Macintosh_128K
# /wiki/Apple_II
# /wiki/IPhone_17_Pro
# /wiki/IPad_Air_(7th_generation)
# /wiki/Apple_Push_Notification_service
# /wiki/Core_Animation
# /wiki/Core_Audio
# /wiki/Liquid_Glass
# /wiki/Health_(Apple)
# /wiki/IPhone_7
# /wiki/IPad
# /wiki/The_Register
# /wiki/InformationWeek
# /wiki/OCLC_(identifier)
# /wiki/Wikimedia_Foundation
# /wiki/Magnus_Manske
# /wiki/WikiConference_India
# /wiki/Mar%C3%ADa_Sefidari
# /wiki/Jimmy_Wales
# /wiki/Wiki_Loves_Folklore
# /wiki/Asian_News_International_vs._Wikimedia_Foundation
# /wiki/Tushar_Rao_Gedela
# /wiki/The_Hindu
# /wiki/The_Siasat_Daily
# /wiki/Chandrika_(newspaper)
# /wiki/Lalu_Leela
# /wiki/Kerala
# /wiki/Bhakti_movement
# /wiki/Tribal_religions_in_India
# /wiki/Religion_in_West_Bengal
# /wiki/ISSN_(identifier)
# /wiki/ISO_6385
# /wiki/Trusted_Platform_Module
# /wiki/Yaboot
# /wiki/AMIBIOS
# /wiki/Device_driver
# /wiki/Inode
# /wiki/Comparison_of_distributed_file_systems
# /wiki/Novell_Storage_Services
# /wiki/Sun_Microsystems
# /wiki/X64
# /wiki/X11
# /wiki/MIT_License
# /wiki/List_of_open-source_codecs
# /wiki/Lossy_compression
# /wiki/Lossless_compression
# /wiki/Adaptive_Huffman_coding
# /wiki/Sound_quality
# /wiki/Delivered_Audio_Quality
# /wiki/Sound_recording_and_reproduction
# /wiki/White-Smith_Music_Publishing_Company_v._Apollo_Company
# /wiki/Copyright_Act_of_1976
# /wiki/Charles_River_Bridge_v._Warren_Bridge
# /wiki/Voss_v._Fisher
# /wiki/O%27Reilly_v._Morse
# /wiki/Article_One_of_the_United_States_Constitution#Enumerated_powers
# /wiki/Felony
# /wiki/Domestic_violence
# /wiki/Sexual_cleansing#Sexual_cleansing_after_menarche
# /wiki/Sex_worker
# /wiki/Sexual_surrogate
# /wiki/Rape
# /wiki/Free_love
# /wiki/%C3%89mile_Armand
# /wiki/Dorothy_Day
# /wiki/Homestead_strike
# /wiki/Reservoir_war
# /wiki/Carroll_County,_Ohio
# /wiki/Republican_Party_(United_States)
# /wiki/Christian_Zionism
# /wiki/Michael_Knowles_(political_commentator)
# /wiki/National_Federation_of_Independent_Business
# /wiki/Ada_Brown_(judge)#Ryan,_LLC_v._FTC
# /wiki/Texas_Highway_Patrol
# /wiki/9-1-1
# /wiki/Emergency_medical_services_in_New_Zealand
# /wiki/Rescue
# /wiki/Rescue_vehicle
# /wiki/International_Firefighters%27_Day
# /wiki/Fire_hose
# /wiki/Water
# /wiki/ISBN_(identifier)
# /wiki/ISO_9
# /wiki/ISO/IEC_11801
# /wiki/Accuracy_and_precision
# /wiki/File_Allocation_Table
# /wiki/Linear_Tape-Open
# /wiki/MicroMV
# /wiki/CV-2000
# /wiki/Betacam#Betacam_SX
# /wiki/D-1_(Sony)
# /wiki/HDV
# /wiki/DV_(video_format)#DVCPRO_HD
# /wiki/8_mm_video_format
# /wiki/Sony_Financial_Group
# /wiki/Anime_on_Demand
# /wiki/2waytraffic
# /wiki/Online_games
# /wiki/Multiplayer_online_battle_arena
# /wiki/Game_Informer
# /wiki/Official_Xbox_Magazine
# /wiki/List_of_Xbox_Series_X_and_Series_S_games
# /wiki/List_of_Ravenscourt_games
# /wiki/Xbox_One
# /wiki/Microsoft_Lumia_650
# /wiki/Surface_Laptop_2
# /wiki/Surface_Laptop_Studio_2
# /wiki/Surface_Pro_(11th_generation)
# /wiki/MacBook_Air_(Apple_silicon)
# /wiki/MacOS
# /wiki/Distributed_operating_system
# /wiki/Cooperative_multitasking
# /wiki/User_space_and_kernel_space
# /wiki/Hybrid_kernel
# /wiki/Mach_(kernel)
# /wiki/GNU
# /wiki/Copyleft
# /wiki/Open_source
# /wiki/ISBN_(identifier)
# /wiki/ISO_639-5
# /wiki/Creoles_and_pidgins,_Portuguese-based
# /wiki/Tranquebar
# /wiki/Thiruthetriyambalam
# /wiki/Garuda
# /wiki/Bombax_ceiba
# /wiki/Hindi_language
# /wiki/Government_of_India
# /wiki/Commander-in-chief
# /wiki/Marine_Corps_Cyber_Auxiliary
# /wiki/Georgia_State_Defense_Force
# /wiki/Oklahoma_State_Guard
# /wiki/Nathan_Dahm
# /wiki/Republican_Party_(United_States)
# /wiki/Continental_Association
# /wiki/Articles_of_Confederation
# /wiki/British_credit_crisis_of_1772%E2%80%931773
# /wiki/Encilhamento
# /wiki/Television_in_Brazil
# /wiki/Television_in_Greenland
# /wiki/Nepal_Television
# /wiki/List_of_programs_broadcast_by_Nepal_Television
# /wiki/List_of_programmes_broadcast_by_Challenge
# /wiki/List_of_programs_broadcast_by_Rede_Globo
# /wiki/Poliana_Abritta
# /wiki/Gl%C3%B3ria_Maria
# /wiki/Rio_de_Janeiro
# /wiki/Religion_in_Brazil
# /wiki/Religion_in_Korea
# /wiki/ISBN_(identifier)
# /wiki/Bookstore
# /wiki/Book_curse
# /wiki/Wayne_A._Wiegand
# /wiki/Walnut_Creek,_California
# /wiki/American_Reprographics_Company
# /wiki/Trade_name
# /wiki/Fair_use
# /wiki/Andrea_Blanch
# /wiki/Brooklyn
# /wiki/1968_United_States_presidential_election_in_New_York
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2124512233.py in <cell line: 0>()
#      19     newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      20     print(newArticle)
# ---> 21     links = getLinks(newArticle)
#
# /tmp/ipython-input-2124512233.py in getLinks(articleUrl)
#      12     html = urlopen(req, timeout=15)
#      13
# ---> 14     bs = BeautifulSoup(html, 'html.parser')
#      15     return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#      16
#
# /usr/local/lib/python3.12/dist-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     474             self.builder.initialize_soup(self)
#     475             try:
# --> 476                 self._feed()
#     477                 success = True
#     478                 break
#
# /usr/local/lib/python3.12/dist-packages/bs4/__init__.py in _feed(self)
#     659
#     660         if self.markup is not None:
# --> 661             self.builder.feed(self.markup)
#     662         # Close out any unfinished strings and close all the open tags.
#     663         self.endData()
#
# /usr/local/lib/python3.12/dist-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     465
#     466         try:
# --> 467             parser.feed(markup)
#     468             parser.close()
#     469         except AssertionError as e:
#
# /usr/lib/python3.12/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /usr/lib/python3.12/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# /usr/lib/python3.12/html/parser.py in parse_starttag(self, i)
#     336             self.handle_startendtag(tag, attrs)
#     337         else:
# --> 338             self.handle_starttag(tag, attrs)
#     339             if tag in self.CDATA_CONTENT_ELEMENTS:
#     340                 self.set_cdata_mode(tag)
#
# /usr/local/lib/python3.12/dist-packages/bs4/builder/_htmlparser.py in handle_starttag(self, tag, attrs, handle_empty_element)
#     180         else:
#     181             sourceline = sourcepos = None
# --> 182         tagObj = self.soup.handle_starttag(
#     183             tag, None, None, attr_dict, sourceline=sourceline, sourcepos=sourcepos
#     184         )
#
# /usr/local/lib/python3.12/dist-packages/bs4/__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#    1033         # the user brought type-unsafety upon themselves.
#    1034         tag_class = cast(Type[Tag], tag_class)
# -> 1035         tag = tag_class(
#    1036             self,
#    1037             self.builder,
#
# /usr/local/lib/python3.12/dist-packages/bs4/element.py in __init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1685         else:
#    1686             if builder is not None and builder.cdata_list_attributes:
# -> 1687                 self.attrs = builder._replace_cdata_list_attribute_values(
#    1688                     self.name, attrs
#    1689                 )
#
# /usr/local/lib/python3.12/dist-packages/bs4/builder/__init__.py in _replace_cdata_list_attribute_values(self, tag_name, attrs)
#     411         for attr in list(modified_attrs.keys()):
#     412             modified_value: _AttributeValue
# --> 413             if attr in universal or (tag_specific and attr in tag_specific):
#     414                 # We have a "class"-type attribute whose string
#     415                 # value is a whitespace-separated list of
#
# KeyboardInterrupt:

# %% [markdown]
# ## Recursively crawling an entire site

# %%
from urllib.request import urlopen,Request
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    req=Request(f'http://en.wikipedia.org{pageUrl}',headers={'User-Agent': 'Mozilla/5.0'})
    html = urlopen(req, timeout=15)
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:SpecialPages
# /wiki/Special:Search
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# /wiki/Special:WhatLinksHere/User_talk:34.28.194.193
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-356216077.py in <cell line: 0>()
#      16                 pages.add(newPage)
#      17                 getLinks(newPage)
# ---> 18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# /tmp/ipython-input-356216077.py in getLinks(pageUrl)
#       6 def getLinks(pageUrl):
#       7     req=Request(f'http://en.wikipedia.org{pageUrl}',headers={'User-Agent': 'Mozilla/5.0'})
# ----> 8     html = urlopen(req, timeout=15)
#       9     bs = BeautifulSoup(html, 'html.parser')
#      10     for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     else:
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
#     217 def install_opener(opener):
#
# /usr/lib/python3.12/urllib/request.py in open(self, fullurl, data, timeout)
#     519         for processor in self.process_response.get(protocol, []):
#     520             meth = getattr(processor, meth_name)
# --> 521             response = meth(req, response)
#     522
#     523         return response
#
# /usr/lib/python3.12/urllib/request.py in http_response(self, request, response)
#     628         # request was successfully received, understood, and accepted.
#     629         if not (200 <= code < 300):
# --> 630             response = self.parent.error(
#     631                 'http', request, response, code, msg, hdrs)
#     632
#
# /usr/lib/python3.12/urllib/request.py in error(self, proto, *args)
#     551             http_err = 0
#     552         args = (dict, proto, meth_name) + args
# --> 553         result = self._call_chain(*args)
#     554         if result:
#     555             return result
#
# /usr/lib/python3.12/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     490         for handler in handlers:
#     491             func = getattr(handler, meth_name)
# --> 492             result = func(*args)
#     493             if result is not None:
#     494                 return result
#
# /usr/lib/python3.12/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     743         fp.close()
#     744
# --> 745         return self.parent.open(new, timeout=req.timeout)
#     746
#     747     http_error_301 = http_error_303 = http_error_307 = http_error_308 = http_error_302
#
# /usr/lib/python3.12/urllib/request.py in open(self, fullurl, data, timeout)
#     519         for processor in self.process_response.get(protocol, []):
#     520             meth = getattr(processor, meth_name)
# --> 521             response = meth(req, response)
#     522
#     523         return response
#
# /usr/lib/python3.12/urllib/request.py in http_response(self, request, response)
#     628         # request was successfully received, understood, and accepted.
#     629         if not (200 <= code < 300):
# --> 630             response = self.parent.error(
#     631                 'http', request, response, code, msg, hdrs)
#     632
#
# /usr/lib/python3.12/urllib/request.py in error(self, proto, *args)
#     557         if http_err:
#     558             args = (dict, 'default', 'http_error_default') + orig_args
# --> 559             return self._call_chain(*args)
#     560
#     561 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.12/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     490         for handler in handlers:
#     491             func = getattr(handler, meth_name)
# --> 492             result = func(*args)
#     493             if result is not None:
#     494                 return result
#
# /usr/lib/python3.12/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     637 class HTTPDefaultErrorHandler(BaseHandler):
#     638     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     640
#     641 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Collecting Data Across an Entire Site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    req=Request(f'http://en.wikipedia.org{pageUrl}',headers={'User-Agent': 'Mozilla/5.0'})
    html = urlopen(req, timeout=15)
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        #mw-parser-output
        bodyContent = bs.find('div', {'id':'bodyContent'}).find_all('p')
        if len(bodyContent):
            print(bodyContent[0])
        print(bs.find(id='ca-edit').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')

    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('/wiki/General-purpose_programming_language')
# Out:
# General-purpose programming language
# <p>In <a class="mw-redirect" href="/wiki/Computer_software" title="Computer software">computer software</a>, a <b>general-purpose programming language</b> (<b>GPL</b>) is a <a href="/wiki/Programming_language" title="Programming language">programming language</a> for building <a href="/wiki/Software" title="Software">software</a> in a wide variety of application <a href="/wiki/Domain_(software_engineering)" title="Domain (software engineering)">domains</a>. Conversely, a <a href="/wiki/Domain-specific_language" title="Domain-specific language">domain-specific programming language</a> (DSL) is used within a specific area. For example, <a href="/wiki/Python_(programming_language)" title="Python (programming language)">Python</a> is a GPL, while <a href="/wiki/SQL" title="SQL">SQL</a> is a DSL for <a href="/wiki/Query_language" title="Query language">querying relational databases</a>.
# </p>
# /w/index.php?title=General-purpose_programming_language&action=edit
# --------------------
# /wiki/Main_Page
# Main Page
# <p><b><a href="/wiki/Socompa" title="Socompa">Socompa</a></b> is a large <a href="/wiki/Stratovolcano" title="Stratovolcano">stratovolcano</a> (composite volcano) on <a href="/wiki/Argentina%E2%80%93Chile_border" title="Argentina–Chile border">the border of Argentina and Chile</a>. It has an elevation of 6,051 metres (19,852 ft) and is part of the Chilean and Argentine <a href="/wiki/Andean_Volcanic_Belt" title="Andean Volcanic Belt">Andean Volcanic Belt</a>. Socompa lies close to the <a href="/wiki/Mountain_pass" title="Mountain pass">pass</a> of the same name where the <a href="/wiki/Salta%E2%80%93Antofagasta_railway" title="Salta–Antofagasta railway">Salta–Antofagasta railway</a> crosses the border. Most of the northwestern slope of Socompa collapsed catastrophically 7,200 years ago to form an extensive <a href="/wiki/Debris_flow" title="Debris flow">debris avalanche</a> deposit. The Socompa collapse is among the largest known on land with a volume of 19.2 cubic kilometres (4.6 cu mi) and a surface area of 490 square kilometres (190 sq mi). After the <a href="/wiki/Volcanic_landslide" title="Volcanic landslide">volcanic landslide</a>, Socompa was rebuilt by the effusion of <a href="/wiki/Lava" title="Lava">lava flows</a> and much of the scar is now filled in. Socompa is also noteworthy for the <a href="/wiki/Organisms_at_high_altitude" title="Organisms at high altitude">high-altitude biotic communities</a> that are bound to <a href="/wiki/Fumarole" title="Fumarole">fumaroles</a> on the mountain. They are well above the sparse regular vegetation in the region, which does not extend up the mountains. The climate on the mountain is cold and dry. (<b><a href="/wiki/Socompa" title="Socompa">Full article...</a></b>)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Contents
# Wikipedia:Contents
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Portal:Current_events
# Portal:Current events
# <p><b>Armed conflicts and attacks</b>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Random
# Scott Ferson (professor)
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Scott_Ferson_(professor)&action=edit
# --------------------
# /wiki/Wikipedia:About
# Wikipedia:About
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Contents
# Help:Contents
# <p>
# <style data-mw-deduplicate="TemplateStyles:r1012508797">.mw-parser-output .helpContents-wrapper{display:flex;flex-wrap:wrap}.mw-parser-output .helpContents-header{flex:1 0 100%;padding-bottom:1em;border-bottom:1px solid #a2a9b1;text-align:center}.mw-parser-output .helpContents-section{position:relative;flex:1 0 50%;min-width:380px;box-sizing:border-box;margin:1em 0;padding-left:30px;padding-right:20px}.mw-parser-output .helpContents-section h2{font-size:21px;padding:0;margin-top:1em;margin-bottom:0.25em;line-height:1.5}.mw-parser-output .helpContents-section ul{margin-left:0;padding-left:0}.mw-parser-output .helpContents-icon{position:absolute;top:25px;left:0;line-height:1;opacity:0.7}.mw-parser-output .helpContents-additional-search{text-align:center;margin-bottom:1em}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Introduction
# Help:Introduction
# <p><style data-mw-deduplicate="TemplateStyles:r1239334454">.mw-parser-output .introtosingle__main{position:relative;box-sizing:border-box;max-width:100%;overflow:hidden;border:1px solid var(--border-color-base,#a2a9b1);margin:auto;padding-bottom:20px}.mw-parser-output .introtosingle__main p{margin-bottom:2.0em}.mw-parser-output .introtosingle__main-withbackground{background-image:url("https://upload.wikimedia.org/wikipedia/commons/d/d9/Wikipedia-logo-v2-o10.svg");background-position:center -500px;background-repeat:no-repeat;background-size:auto 150%}.mw-parser-output .introtosingle__main-title{font-size:250%;line-height:150%;background:#777;color:#FFF;text-align:center;font-weight:bold}.mw-parser-output .introtosingle__lead{background-color:#EEE;background-color:rgba(221,221,221,0.5);padding:30px 60px;margin-bottom:15px}.mw-parser-output .introtosingle__base{box-sizing:border-box;max-width:1100px;min-height:55px;margin:auto;padding:5px 20px;font-size:1.1em;background:var(--background-color-interactive,#eaecf0);border:1px solid var(--border-color-subtle,#c8ccd1);border-top:0}.mw-parser-output .introtosingle__columns{display:flex;flex-direction:row;flex-wrap:wrap-reverse;justify-content:center}.mw-parser-output .introtosingle__columns-left,.mw-parser-output .introtosingle__columns-left-noborder,.mw-parser-output .introtosingle__columns-right{display:inline-block;flex:1 1 0;align-self:flex-end;vertical-align:top;min-width:200px;max-width:300px;padding:10px}.mw-parser-output .introtosingle__columns-left{text-align:right;justify-content:right;border-right:solid 1px #ddd}.mw-parser-output .introtosingle__columns-left-noborder{text-align:right;justify-content:right}.mw-parser-output .introtosingle__columns-right{text-align:left;justify-content:left}@media screen and (min-width:1101px){.mw-parser-output .introtosingle__main{max-width:1100px}}@media screen{html.skin-theme-clientpref-night .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}html.skin-theme-clientpref-night .mw-parser-output .introtosingle__main-title{background-color:#24282c}}@media screen and (prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .introtosingle__main-title{background-color:#24282c}html.skin-theme-clientpref-os .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Community_portal
# Wikipedia:Community portal
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:RecentChanges
# Recent changes
# <p>This is a list of recent changes to Wikipedia.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:File_upload_wizard
# Wikipedia:File upload wizard
# <p>Thank you for offering to contribute an image or other media file for use on Wikipedia. This wizard will guide you through a questionnaire prompting you for the appropriate copyright and sourcing information for each file. Please ensure you understand <a href="/wiki/Wikipedia:Copyrights" title="Wikipedia:Copyrights">copyright</a> and the <a href="/wiki/Wikipedia:Image_use_policy" title="Wikipedia:Image use policy">image use policy</a> before proceeding.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:SpecialPages
# Special pages
# <p>This page contains a list of <a href="/wiki/Help:Special_page" title="Help:Special page">special pages</a>. Most of the content of these pages is automatically generated and cannot be edited. To suggest a change to the parts that <i>can</i> be edited, find the appropriate text on <a href="/wiki/Special:AllMessages" title="Special:AllMessages">Special:AllMessages</a> and then request your change on the talk page of the message (using {{<a href="/wiki/Template:Edit_fully-protected" title="Template:Edit fully-protected">editprotected</a>}} to draw the attention of administrators).
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Search
# Search
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyContributions
# User contributions for 34.28.194.193
# <p>This user or IP address is currently <a class="extiw" href="https://meta.wikimedia.org/wiki/global_blocks" title="m:global blocks">globally blocked</a>.
# If the block is marked as locally disabled, this means that it applies on other sites, but a local administrator has decided to disable it on this wiki.
# The global block log entry is provided below for reference:
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyTalk
# User talk:34.28.194.193
# <p>People on Wikipedia can use this <a href="/wiki/Wikipedia:User_pages" title="Wikipedia:User pages">talk page</a> to post a public message about edits made from the IP address you are currently using.
# </p>
# /w/index.php?title=User_talk:34.28.194.193&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/User_talk:34.28.194.193
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-1943825557.py in <cell line: 0>()
#      27                 pages.add(newPage)
#      28                 getLinks(newPage)
# ---> 29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#      26                 print(newPage)
#      27                 pages.add(newPage)
# ---> 28                 getLinks(newPage)
#      29 getLinks('/wiki/General-purpose_programming_language')
#
# /tmp/ipython-input-1943825557.py in getLinks(pageUrl)
#       6 def getLinks(pageUrl):
#       7     req=Request(f'http://en.wikipedia.org{pageUrl}',headers={'User-Agent': 'Mozilla/5.0'})
# ----> 8     html = urlopen(req, timeout=15)
#       9     bs = BeautifulSoup(html, 'html.parser')
#      10     try:
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     else:
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
#     217 def install_opener(opener):
#
# /usr/lib/python3.12/urllib/request.py in open(self, fullurl, data, timeout)
#     519         for processor in self.process_response.get(protocol, []):
#     520             meth = getattr(processor, meth_name)
# --> 521             response = meth(req, response)
#     522
#     523         return response
#
# /usr/lib/python3.12/urllib/request.py in http_response(self, request, response)
#     628         # request was successfully received, understood, and accepted.
#     629         if not (200 <= code < 300):
# --> 630             response = self.parent.error(
#     631                 'http', request, response, code, msg, hdrs)
#     632
#
# /usr/lib/python3.12/urllib/request.py in error(self, proto, *args)
#     551             http_err = 0
#     552         args = (dict, proto, meth_name) + args
# --> 553         result = self._call_chain(*args)
#     554         if result:
#     555             return result
#
# /usr/lib/python3.12/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     490         for handler in handlers:
#     491             func = getattr(handler, meth_name)
# --> 492             result = func(*args)
#     493             if result is not None:
#     494                 return result
#
# /usr/lib/python3.12/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     743         fp.close()
#     744
# --> 745         return self.parent.open(new, timeout=req.timeout)
#     746
#     747     http_error_301 = http_error_303 = http_error_307 = http_error_308 = http_error_302
#
# /usr/lib/python3.12/urllib/request.py in open(self, fullurl, data, timeout)
#     519         for processor in self.process_response.get(protocol, []):
#     520             meth = getattr(processor, meth_name)
# --> 521             response = meth(req, response)
#     522
#     523         return response
#
# /usr/lib/python3.12/urllib/request.py in http_response(self, request, response)
#     628         # request was successfully received, understood, and accepted.
#     629         if not (200 <= code < 300):
# --> 630             response = self.parent.error(
#     631                 'http', request, response, code, msg, hdrs)
#     632
#
# /usr/lib/python3.12/urllib/request.py in error(self, proto, *args)
#     557         if http_err:
#     558             args = (dict, 'default', 'http_error_default') + orig_args
# --> 559             return self._call_chain(*args)
#     560
#     561 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.12/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     490         for handler in handlers:
#     491             func = getattr(handler, meth_name)
# --> 492             result = func(*args)
#     493             if result is not None:
#     494                 return result
#
# /usr/lib/python3.12/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     637 class HTTPDefaultErrorHandler(BaseHandler):
#     638     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     640
#     641 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Crawling across the Internet

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, url):
    netloc = urlparse(url).netloc
    scheme = urlparse(url).scheme
    internalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc == '':
            internalLinks.add(f'{scheme}://{netloc}/{link.attrs["href"].strip("/")}')
        elif parsed.netloc == netloc:
            internalLinks.add(link.attrs['href'])
    return list(internalLinks)

#Retrieves a list of all external links found on a page
def getExternalLinks(bs, url):
    netloc = urlparse(url).netloc
    externalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc != '' and parsed.netloc != netloc:
            externalLinks.add(link.attrs['href'])
    return list(externalLinks)

def getRandomExternalLink(startingPage):
    bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
    externalLinks = getExternalLinks(bs, startingPage)
    if not len(externalLinks):
        print('No external links, looking around the site for one')
        internalLinks = getInternalLinks(bs, startingPage)
        return getRandomExternalLink(random.choice(internalLinks))
    else:
        return random.choice(externalLinks)

def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print(f'Random external link is: {externalLink}')
    followExternalOnly(externalLink)


followExternalOnly('https://www.oreilly.com/')
# Out:
# Random external link is: https://www.oreilly.co.jp/index.shtml
# Random external link is: https://store.kinokuniya.co.jp/store/shinjuku-main-store/
# Random external link is: https://www.kinokuniya.co.jp/f/dsd-107004001041005002--
# Random external link is: https://www.kinokuniya.com/
# Random external link is: https://uae.kinokuniya.com/
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-3536310216.py in <cell line: 0>()
#      49
#      50
# ---> 51 followExternalOnly('https://www.oreilly.com/')
#
# /tmp/ipython-input-3536310216.py in followExternalOnly(startingSite)
#      46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
# ---> 48     followExternalOnly(externalLink)
#      49
#      50
#
# /tmp/ipython-input-3536310216.py in followExternalOnly(startingSite)
#      46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
# ---> 48     followExternalOnly(externalLink)
#      49
#      50
#
# /tmp/ipython-input-3536310216.py in followExternalOnly(startingSite)
#      46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
# ---> 48     followExternalOnly(externalLink)
#      49
#      50
#
# /tmp/ipython-input-3536310216.py in followExternalOnly(startingSite)
#      46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
# ---> 48     followExternalOnly(externalLink)
#      49
#      50
#
# /tmp/ipython-input-3536310216.py in followExternalOnly(startingSite)
#      46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
# ---> 48     followExternalOnly(externalLink)
#      49
#      50
#
# /tmp/ipython-input-3536310216.py in followExternalOnly(startingSite)
#      44
#      45 def followExternalOnly(startingSite):
# ---> 46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
#      48     followExternalOnly(externalLink)
#
# /tmp/ipython-input-3536310216.py in getRandomExternalLink(startingPage)
#      34
#      35 def getRandomExternalLink(startingPage):
# ---> 36     bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
#      37     externalLinks = getExternalLinks(bs, startingPage)
#      38     if not len(externalLinks):
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     else:
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
#     217 def install_opener(opener):
#
# /usr/lib/python3.12/urllib/request.py in open(self, fullurl, data, timeout)
#     519         for processor in self.process_response.get(protocol, []):
#     520             meth = getattr(processor, meth_name)
# --> 521             response = meth(req, response)
#     522
#     523         return response
#
# /usr/lib/python3.12/urllib/request.py in http_response(self, request, response)
#     628         # request was successfully received, understood, and accepted.
#     629         if not (200 <= code < 300):
# --> 630             response = self.parent.error(
#     631                 'http', request, response, code, msg, hdrs)
#     632
#
# /usr/lib/python3.12/urllib/request.py in error(self, proto, *args)
#     557         if http_err:
#     558             args = (dict, 'default', 'http_error_default') + orig_args
# --> 559             return self._call_chain(*args)
#     560
#     561 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.12/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     490         for handler in handlers:
#     491             func = getattr(handler, meth_name)
# --> 492             result = func(*args)
#     493             if result is not None:
#     494                 return result
#
# /usr/lib/python3.12/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     637 class HTTPDefaultErrorHandler(BaseHandler):
#     638     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     640
#     641 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# ## Collect all External Links from a Site

# %%
# Collects a list of all external URLs found on the site
allExtLinks = []
allIntLinks = []


def getAllExternalLinks(url):
    bs = BeautifulSoup(urlopen(url), 'html.parser')
    internalLinks = getInternalLinks(bs, url)
    externalLinks = getExternalLinks(bs, url)
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.append(link)
            print(link)

    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.append(link)
            getAllExternalLinks(link)


allIntLinks.append('https://oreilly.com')
getAllExternalLinks('https://www.oreilly.com/')
# Out:
# https://learning.oreilly.com/search/?query=author%3A%22Sari%20Greene%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Bruno%20Gon%C3%A7alves%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Neal%20Ford%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Kelsey%20Hightower%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://itunes.apple.com/us/app/safari-to-go/id881697395
# https://learning.oreilly.com/start-trial/
# https://learning.oreilly.com/search/?query=author%3A%22Arianne%20Dee%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=suggestion&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.linkedin.com/company/oreilly-media
# https://www.oreilly.co.jp/index.shtml
# https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# https://learning.oreilly.com/search/?query=author%3A%22Ken%20Kousen%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://play.google.com/store/apps/details?id=com.safariflow.queue
# https://www.youtube.com/user/OreillyMedia
# https://channelstore.roku.com/details/c9d25fa651f0ad84e484b0dfd4b20172:856a240ad268961983e91ae52c1e1e5c/oreilly
# http://app.impact.com/campaign-campaign-info-v2/OReilly-Media.brand?io=6f/qSfrgIgnzAf6MUZzqf6HTqjloxZsYQDW+fEiPohw9rurZxUhQ9o6ZWNsuSDhl
# https://learning.oreilly.com
# https://creativecommons.org/licenses/by-sa/3.0/
# https://learning.oreilly.com/membership-agreement/
# https://www.copyright.gov/title17/92chap1.html#107
# http://shop.oreilly.com/
# http://members.oreilly.com
# http://fb.co/OReilly
# http://getsatisfaction.com/oreilly
# http://twitter.com/oreillymedia
# http://shop.oreilly.com/category/customer-service.do
# https://www.safaribooksonline.com/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170601+nav
# http://oreilly.com/oreilly/privacy.html
# https://www.youtube.com/watch?v=6QZJtH7JcT8
# https://www.youtube.com/watch?v=WruTEJ3uv3M
# https://www.youtube.com/watch?v=S1GmV5iKCkM
# https://asimovaddendum.substack.com/p/ai-disclosures-project-year-in-review
# https://asimovaddendum.substack.com/p/read-write-act-inside-the-mcp-server
# https://www.youtube.com/watch?v=nhhoiLF9QL8
# https://learning.oreilly.com/signup/
# http://oreilly.com/catalog/0790145317780
# http://www.oreillynet.com/pub/au/1798
# http://oreilly.com/catalog/0790145317780/
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-1686607757.py in <cell line: 0>()
#      20
#      21 allIntLinks.append('https://oreilly.com')
# ---> 22 getAllExternalLinks('https://www.oreilly.com/')
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# /tmp/ipython-input-1686607757.py in getAllExternalLinks(url)
#       5
#       6 def getAllExternalLinks(url):
# ----> 7     bs = BeautifulSoup(urlopen(url), 'html.parser')
#       8     internalLinks = getInternalLinks(bs, url)
#       9     externalLinks = getExternalLinks(bs, url)
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     else:
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
#     217 def install_opener(opener):
#
# /usr/lib/python3.12/urllib/request.py in open(self, fullurl, data, timeout)
#     519         for processor in self.process_response.get(protocol, []):
#     520             meth = getattr(processor, meth_name)
# --> 521             response = meth(req, response)
#     522
#     523         return response
#
# /usr/lib/python3.12/urllib/request.py in http_response(self, request, response)
#     628         # request was successfully received, understood, and accepted.
#     629         if not (200 <= code < 300):
# --> 630             response = self.parent.error(
#     631                 'http', request, response, code, msg, hdrs)
#     632
#
# /usr/lib/python3.12/urllib/request.py in error(self, proto, *args)
#     557         if http_err:
#     558             args = (dict, 'default', 'http_error_default') + orig_args
# --> 559             return self._call_chain(*args)
#     560
#     561 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.12/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     490         for handler in handlers:
#     491             func = getattr(handler, meth_name)
# --> 492             result = func(*args)
#     493             if result is not None:
#     494                 return result
#
# /usr/lib/python3.12/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     637 class HTTPDefaultErrorHandler(BaseHandler):
#     638     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     640
#     641 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found
